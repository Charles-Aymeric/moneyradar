# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Moneyradar/nvidia_gold_bitcoin.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1597 non-null   object
#  1   Rendement_Bitcoin  1597 non-null   float64
#  2   Rendement_gold     1139 non-null   float64
#  3   Rendement_nvidia   1099 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 50.0+ KB

# %%
df['Date']=pd.to_datetime(df.Date)

# %%
df=df.fillna(method='backfill')
df=df.fillna(method='ffill')

# %%
rendement_columns = ['Rendement_Bitcoin', 'Rendement_gold', 'Rendement_nvidia']
df[rendement_columns] = df[rendement_columns] - 100

# %%
df.head()
# Out:
#         Date  Rendement_Bitcoin  Rendement_gold  Rendement_nvidia
# 0 2020-01-01           0.000000        0.000000          0.000000
# 1 2020-01-02          -3.233423        0.000000          0.000000
# 2 2020-01-03           1.990333        1.590210         -1.600534
# 3 2020-01-04           2.458402        2.663438         -1.183728
# 4 2020-01-05           2.398678        2.663438         -1.183728

# %%
print(df[df.Rendement_nvidia.isnull()])
# Out:
# Empty DataFrame
# Columns: [Date, Rendement_Bitcoin, Rendement_gold, Rendement_nvidia]
# Index: []

# %%
# !pip install plotly

# %%
# import plotly.graph_objects as go
# import pandas as pd

# # Assurez-vous que le DataFrame df est correctement défini et contient une colonne 'Date'
# # df = votre DataFrame

# # Convertir la colonne Date en index si ce n'est pas déjà fait
# if 'Date' in df.columns:
#     df.set_index('Date', inplace=True)

# # Créer une figure
# fig = go.Figure()

# # Ajouter des traces pour chaque colonne de rendement
# for column in df.columns:
#     fig.add_trace(go.Scatter(x=df.index, y=df[column], mode='lines', name=column))

# # Configurer les frames pour l'animation
# frames = [
#     go.Frame(
#         data=[go.Scatter(x=df.index[:k], y=df[column][:k], mode='lines', name=column) for column in df.columns],
#         name=str(k)
#     ) for k in range(1, len(df) + 1)
# ]

# fig.frames = frames

# # Ajouter des boutons de contrôle pour l'animation
# fig.update_layout(
#     updatemenus=[{
#         "type": "buttons",
#         "buttons": [
#             {
#                 "label": "Play",
#                 "method": "animate",
#                 "args": [None, {"frame": {"duration": 100, "redraw": True}, "fromcurrent": True}]
#             },
#             {
#                 "label": "Pause",
#                 "method": "animate",
#                 "args": [[None], {"frame": {"duration": 0, "redraw": True}, "mode": "immediate"}]
#             }
#         ]
#     }]
# )

# # Configurer la mise en page de la figure
# fig.update_layout(
#     title='Évolution des rendements au fil du temps',
#     xaxis_title='Date',
#     yaxis_title='Rendement',
#     showlegend=True,
#     height=600  # Ajuster la hauteur de la figure pour améliorer la lisibilité
# )

# # Afficher la figure
# import plotly.io as pio
# pio.show(fig)

# %%
df.to_csv('rendement_gold.csv')
